# %% [markdown]
# # 02 Feature Engineering
#
# Review percentile-based scores and profile features.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from data_loader import load_player_data

df = load_player_data(refresh=True)
score_cols = ['attacking_score', 'creativity_score', 'progression_score', 'defensive_score', 'possession_score', 'overall_score']
df.groupby('position')[score_cols].mean().round(1)
