# %% [markdown]
# # 03 Model Training
#
# Train the transparent first-pass model against the heuristic success label.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from data_loader import load_player_data
from model import train_success_model

df = load_player_data()
summary = train_success_model(df)
summary['auc'], summary['feature_importance'].head(10)
