# %% [markdown]
# # 04 Dashboard Prototype
#
# Sketch chart calls used by the Streamlit dashboard.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from data_loader import load_player_data
from visualisations import create_market_value_vs_score_chart

df = load_player_data()
create_market_value_vs_score_chart(df)
