# %% [markdown]
# # 01 Data Exploration
#
# Load the sample player pool, inspect coverage, and review basic distributions.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from data_loader import load_player_data

df = load_player_data()
df.head()

# %%
df[['age', 'market_value_eur', 'minutes', 'success_probability']].describe()
